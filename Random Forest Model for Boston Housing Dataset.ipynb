# %% [markdown]
# ## Import Libraries

# %%
# Import the necessary libraries for the data analysis and visualization

import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import metrics
from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load the boston dataset from sklearn library

from sklearn.datasets import load_boston
boston_dataset = load_boston()

# %%
# Get important keys of the dataset

print(boston_dataset.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
# Get the key named data of the dataset


boston_dataset['data']
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
# Put the dataset into proper format/DataFrames and show the intial five rows of the data


boston = pd.DataFrame(boston_dataset.data, columns=boston_dataset.feature_names)
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
# Lets Filter the rows where 'CHAS' value is set to 0

print(boston[boston.CHAS==0])
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
# We see that there is no price/target column in the dataset whose basis we did the prediction
# Let's add the column price sort all the other values of the housing dataset

boston['House_price'] = boston_dataset.target
boston.sort_values('House_price',ascending=False)
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 283   0.01501  90.0   1.21   1.0  0.401  7.923   24.8  5.8850   1.0  198.0
# 225   0.52693   0.0   6.20   0.0  0.504  8.725   83.0  2.8944   8.0  307.0
# 369   5.66998   0.0  18.10   1.0  0.631  6.683   96.8  1.3567  24.0  666.0
# 370   6.53876   0.0  18.10   1.0  0.631  7.016   97.5  1.2024  24.0  666.0
# 371   9.23230   0.0  18.10   0.0  0.631  6.216  100.0  1.1691  24.0  666.0
# ..        ...   ...    ...   ...    ...    ...    ...     ...   ...    ...
# 414  45.74610   0.0  18.10   0.0  0.693  4.519  100.0  1.6582  24.0  666.0
# 399   9.91655   0.0  18.10   0.0  0.693  5.852   77.8  1.5004  24.0  666.0
# 400  25.04610   0.0  18.10   0.0  0.693  5.987  100.0  1.5888  24.0  666.0
# 398  38.35180   0.0  18.10   0.0  0.693  5.453  100.0  1.4896  24.0  666.0
# 405  67.92080   0.0  18.10   0.0  0.693  5.683  100.0  1.4254  24.0  666.0
#
#      PTRATIO       B  LSTAT  House_price
# ...

# %% [markdown]
# ## Bivariate Plots of the Dataset

# %%
# Print the bivariates of the plot of the data where price of the house is not equal to 50

feature_cols = set(boston.columns) - set(['House_price'])
boston1 = boston[boston['House_price'] != 50]
fig, axs = plt.subplots(ncols=7, nrows=2, figsize=(12, 6))
for i, feature in enumerate(feature_cols):
    sns.regplot(x=feature, y='House_price', data=boston1, ax=axs[int(i/7), i%7])

# %%
# Print the Bivariate plots of the data where house price is equal to 50

boston1 = boston[boston['House_price'] == 50]
fig, axs = plt.subplots(ncols=7, nrows=2, figsize=(12, 6))
for i, feature in enumerate(feature_cols):
    sns.regplot(x=feature, y='House_price', data=boston1, ax=axs[int(i/7), i%7])

# %%
# Label the data whise house price is not equal to 50 and put it into another variable

boston=boston[boston.House_price!=50]

# %%
# Sort the values of the house price whose price is less then 50

boston.sort_values('House_price',ascending=False)
# Out:
#          CRIM    ZN  INDUS  CHAS     NOX     RM    AGE     DIS   RAD    TAX  \
# 262   0.52014  20.0   3.97   0.0  0.6470  8.398   91.5  2.2885   5.0  264.0
# 203   0.03510  95.0   2.68   0.0  0.4161  7.853   33.2  5.1180   4.0  224.0
# 233   0.33147   0.0   6.20   0.0  0.5070  8.247   70.4  3.6519   8.0  307.0
# 228   0.29819   0.0   6.20   0.0  0.5040  7.686   17.0  3.3751   8.0  307.0
# 282   0.06129  20.0   3.33   1.0  0.4429  7.645   49.7  5.2119   5.0  216.0
# ..        ...   ...    ...   ...     ...    ...    ...     ...   ...    ...
# 489   0.18337   0.0  27.74   0.0  0.6090  5.414   98.3  1.7554   4.0  711.0
# 399   9.91655   0.0  18.10   0.0  0.6930  5.852   77.8  1.5004  24.0  666.0
# 400  25.04610   0.0  18.10   0.0  0.6930  5.987  100.0  1.5888  24.0  666.0
# 405  67.92080   0.0  18.10   0.0  0.6930  5.683  100.0  1.4254  24.0  666.0
# 398  38.35180   0.0  18.10   0.0  0.6930  5.453  100.0  1.4896  24.0  666.0
#
#      PTRATIO       B  LSTAT  House_price
# ...

# %% [markdown]
# ## Missing Values

# %%
# Check is there any null rows in the dataset

boston.isnull().sum()
# Out:
# CRIM           0
# ZN             0
# INDUS          0
# CHAS           0
# NOX            0
# RM             0
# AGE            0
# DIS            0
# RAD            0
# TAX            0
# PTRATIO        0
# B              0
# LSTAT          0
# House_price    0
# dtype: int64

# %%
# Check if there is any duplicate rows into the dataset


boston[boston.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, House_price]
# Index: []

# %%
# Check the shape of the data

boston.shape
# Out:
# (490, 14)

# %%
# Check the datatypes of the values

boston.dtypes
# Out:
# CRIM           float64
# ZN             float64
# INDUS          float64
# CHAS           float64
# NOX            float64
# RM             float64
# AGE            float64
# DIS            float64
# RAD            float64
# TAX            float64
# PTRATIO        float64
# B              float64
# LSTAT          float64
# House_price    float64
# dtype: object

# %%
# Check how many uniques values in the dataset

boston.nunique()
# Out:
# CRIM           489
# ZN              26
# INDUS           74
# CHAS             2
# NOX             80
# RM             431
# AGE            350
# DIS            398
# RAD              9
# TAX             64
# PTRATIO         44
# B              342
# LSTAT          442
# House_price    228
# dtype: int64

# %%
# Plot a graph to check the relationship b/w the LSTAT, RM, PTRATIO and IDUS with the price

plt.figure(figsize = (20, 5))

features = ['LSTAT', 'RM', 'PTRATIO', 'INDUS']
target = boston['House_price']

for i, col in enumerate(features):
    plt.subplot(1, len(features), i + 1)
    x = boston[col]
    y = target
    plt.scatter(x, y, marker = 'o')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('MEDV')

# %%
# Let's do some statistice of the data

boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  490.000000  490.000000  490.000000  490.000000  490.000000  490.000000
# mean     3.643241   11.112245   11.113143    0.059184    0.554307    6.245471
# std      8.722154   22.844626    6.821302    0.236209    0.116688    0.653147
# min      0.006320    0.000000    0.740000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.881000
# 50%      0.247510    0.000000    9.690000    0.000000    0.538000    6.185000
# 75%      3.647423   12.500000   18.100000    0.000000    0.624000    6.578000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#              AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  490.00000  490.000000  490.000000  490.000000  490.000000  490.000000
# mean    68.27898    3.834519    9.514286  408.002041   18.520000  355.855449
# ...

# %%
# Let's create a distribution plot of the House Price 

sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(boston['House_price'], bins=30)
plt.show()

# %%
# Create a Correlation graph , as we can easily visualize our data with more efficient way

correlation_matrix = boston.corr().round(2)
sns.heatmap(data=correlation_matrix, annot=True)

# %%
# Lets put the four columns in one variable and put house price column in another variable to make our predictions better

X = pd.DataFrame(np.c_[boston['LSTAT'], boston['RM'],boston['PTRATIO'],boston['INDUS']], columns = ['LSTAT','RM','PTRATIO','INDUS'])
y = boston['House_price']
print(X)
print(Y)
# Out:
#      LSTAT     RM  PTRATIO  INDUS
# 0     4.98  6.575     15.3   2.31
# 1     9.14  6.421     17.8   7.07
# 2     4.03  7.185     17.8   7.07
# 3     2.94  6.998     18.7   2.18
# 4     5.33  7.147     18.7   2.18
# ..     ...    ...      ...    ...
# 485   9.67  6.593     21.0  11.93
# 486   9.08  6.120     21.0  11.93
# 487   5.64  6.976     21.0  11.93
# 488   6.48  6.794     21.0  11.93
# 489   7.88  6.030     21.0  11.93
#
# [490 rows x 4 columns]
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: House_price, Length: 490, dtype: float64

# %% [markdown]
# ## Model Development

# %%
# Let's Development our Model and split the data into train test subsets

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (343, 4)
# (147, 4)
# (343,)
# (147,)

# %%
# Import Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor

# Create a Random Forest Regressor
reg = RandomForestRegressor()

# %%
# Now lets calculate the Root Mean Squared Error of our model 

from sklearn import model_selection
import math

print("Root Mean Square Error (RMSE) score\n")
scoring = 'neg_mean_squared_error'
kfold = model_selection.KFold(n_splits=10, random_state=42,shuffle=True)
cv = model_selection.cross_val_score(reg, X_train, y_train, cv=kfold, scoring=scoring)
sqrt_cv = [math.sqrt(abs(i)) for i in cv]
print("{} ({})".format( np.mean(sqrt_cv), np.std(sqrt_cv)))
print('Result from each iteration of cross validation:', cv, '\n')
# Out:
# Root Mean Square Error (RMSE) score
#
# 3.3262222601334956 (0.8381687411932184)
# Result from each iteration of cross validation: [ -9.96903517 -24.59758846 -11.47589911  -5.31290397  -7.23875212
#   -6.31003412 -15.26977482  -9.89063291 -20.42609438  -7.17209856]

# %%
# Now, let's calculate the R-squared value for the model

print("R-squared Value\n")
scoring = 'r2'
kfold = model_selection.KFold(n_splits=10, random_state=42,shuffle=True)
cv = model_selection.cross_val_score(reg, X_train, y_train, cv=kfold, scoring=scoring)
print("{} ({})".format( cv.mean(), cv.std()))
print('Result from each iteration of cross validation:', cv, '\n')
# Out:
# R-squared Value
#
# 0.818201588890117 (0.0754693527108037)
# Result from each iteration of cross validation: [0.87082744 0.66820575 0.79314385 0.91366568 0.86620777 0.90155065
#  0.77708589 0.81707907 0.71977589 0.85447389]
